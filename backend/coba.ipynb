# %%
from jinja2 import Template

# %%
data = {
    "report_date": "20-12-2024",
    "avg_wob": 120,
    "avg_rop": 30,
    "avg_rpm": 85,
    "torque": 500,
    "stand_pipe_pressure": 1500,
    "flow_rate": 500,
    "string_weight": 10,
    "rotating_weight": 8,
    "total_drilling_time": 72,
    "circulating_pressure": 1200,
    "daily_cost": 25000,
    "daily_mud_cost": 3000,
    "day_supervisor": "John Doe",
    "night_supervisor": "Jane Smith",
    "engineer": "Dr. Engineer",
    "geologist": "Dr. Geologist",
    "day_summary": "Drilling operations ran smoothly.",
    "day_forecast": "Expected to reach target depth tomorrow.",
    "time_breakdown": [
        {
            "start_time": "00:00",
            "end_time": "07:00",
            "elapsed": "07:00",
            "start_measured_depth": 4702,
            "end_measured_depth": 4702,
            "ft_length": 0,
            "category": "Workover",
            "p": "Y",
            "npt": "P",
            "code": "p. Other",
            "operation": "Cabut dan setup rangkaian 7\" Packer dari kedalaman 1279.69 mMD sampai ke permukaan."
        },
        {
            "start_time": "07:00",
            "end_time": "16:00",
            "elapsed": "09:00",
            "start_measured_depth": 4702,
            "end_measured_depth": 4702,
            "ft_length": 0,
            "category": "Workover",
            "p": "Y",
            "npt": "P",
            "code": "p. Other",
            "operation": "MU & masuk RPP (Tubing plug 2.78\") di kedalaman 1274.67 mMD."
        },
        {
            "start_time": "16:00",
            "end_time": "18:00",
            "elapsed": "02:00",
            "start_measured_depth": 4702,
            "end_measured_depth": 4702,
            "ft_length": 0,
            "category": "Workover",
            "p": "Y",
            "npt": "P",
            "code": "p. Other",
            "operation": "N/D BOP Group 7-1/16\" x 3000 Psi. N/D BOP Nipple dan flow line."
        },
        {
            "start_time": "18:00",
            "end_time": "24:00",
            "elapsed": "06:00",
            "start_measured_depth": 4702,
            "end_measured_depth": 4702,
            "ft_length": 0,
            "category": "Workover",
            "p": "Y",
            "npt": "P",
            "code": "p. Other",
            "operation": "MU dan masuk RBI. Rabbit dan hammering semua tubular yang masuk."
        },
    ]
}

# Baca template HTML
with open("/home/linuxelementary/Documents/DOR (Repaired) baru-2.htm", "r") as file:
    html_template = file.read()

# Ganti placeholder dengan nilai dari data
for key, value in data.items():
    html_template = html_template.replace(f"{{{key}}}", str(value))

# Menyimpan hasil ke file baru
output_path = "/home/linuxelementary/Documents/DOR (Replaced).htm"
with open(output_path, "w") as file:
    file.write(html_template)

print(f"Template berhasil diisi dan disimpan ke {output_path}")
# Out:
# Template berhasil diisi dan disimpan ke /home/linuxelementary/Documents/DOR (Replaced).htm

# %%
import random
import datetime

# %%
from datetime import datetime, date, time

# Define your time objects
time1 = time(4, 51, 18, 403000)
time2 = time(4, 51, 19, 403000)

# Combine time objects with a common date
datetime1 = datetime.combine(date.min, time1)
datetime2 = datetime.combine(date.min, time2)

# Calculate the difference
time_difference = datetime2 - datetime1

# Convert the difference to total seconds
total_seconds = time_difference.total_seconds()


hours = int(total_seconds // 3600)
minutes = int((total_seconds % 3600) // 60)

# Create a time object for the difference
time_difference_obj = time(hours, minutes)
# Out:
# 1.0

# %%
hours
# Out:
# 0.0

# %%
datetime1.time()
# Out:
# datetime.time(4, 51, 18, 403000)

# %%
from datetime import datetime, date, time
from decimal import Decimal
from enum import Enum

# Definisikan enum yang digunakan
class YesNo(Enum):
    Y = 'Y'
    N = 'N'

class JobCategory(Enum):
    DRILLING = 'DRILLING'
    COMPLETION = 'COMPLETION'
    WORKOVER = 'WORKOVER'

class NPT(Enum):
    NP = 'NP'
    NPT = 'NPT'

class OperationCode(Enum):
    RIG_UP_TEAR_DOWN = '(1) Rig Up and Tear Down'
    DRILLING_OPERATIONS = '(2) Drilling Operations'

class BHAComponentType(Enum):
    BUMPER_SUB = 'Bumper Sub'
    STABILIZER = 'Stabilizer'
    BIT = 'Bit'

class MudType(Enum):
    LIQUID = 'LIQUID'
    GAS = 'GAS'

# Dictionary data
data = {
    'avg_wob': 0.0,
    'avg_rop': 0.0,
    'avg_rpm': 0.0,
    'torque': 0.0,
    'stand_pipe_pressure': 0.0,
    'flow_rate': 0.0,
    'string_weight': 0.0,
    'rotating_weight': 0.0,
    'total_drilling_time': 0.0,
    'circulating_pressure': 0.0,
    'daily_cost': 0.0,
    'daily_mud_cost': 0.0,
    'day_supervisor': 'string',
    'night_supervisor': 'string',
    'engineer': 'string',
    'geologist': 'string',
    'day_summary': 'string',
    'day_forecast': 'string',
    'last_size': 0.0,
    'set_md': 0.0,
    'next_size': 0.0,
    'next_set_md': 0.0,
    'last_lot_emw': 0.0,
    'tol': 0.0,
    'start_mud_volume': 0.0,
    'lost_surface_mud_volume': 0.0,
    'lost_dh_mud_volume': 0.0,
    'dumped_mud_volume': 0.0,
    'built_mud_volume': 0.0,
    'ending_mud_volume': 0.0,
    'max_gas': 0.0,
    'conn_gas': 0.0,
    'trip_gas': 0.0,
    'back_gas': 0.0,
    'annular_velocity': 0.0,
    'pb': 0.0,
    'sys_hhp': 0.0,
    'hhpb': 0.0,
    'hsi': 0.0,
    'percent_psib': 0.0,
    'jet_velocity': 0.0,
    'impact_force': 0.0,
    'if_area': 0.0,
    'stop_cards': 0,
    'lta': YesNo.Y,
    'spill': YesNo.Y,
    'h2s_test': YesNo.Y,
    'hse_mtg': YesNo.Y,
    'kicktrip': YesNo.Y,
    'kickdrill': YesNo.Y,
    'fire': YesNo.Y,
    'personnel': [
        {'company': 'string', 'people': 0}
    ],
    'incidents': [
        {
            'incidents_time': time(4, 51, 19, 403000),
            'incident': 'string',
            'incident_type': 'string',
            'comments': 'string'
        }
    ],
    'time_breakdowns': [
        {
            'start_time': time(4, 51, 18, 403000),
            'end_time': time(4, 55, 19, 403000),
            'start_measured_depth': 0.0,
            'end_measured_depth': 0.0,
            'category': JobCategory.DRILLING,
            'p': YesNo.Y,
            'npt': NPT.NP,
            'code': OperationCode.RIG_UP_TEAR_DOWN,
            'operation': 'string'
        },
        {
            'start_time': time(4, 51, 18, 403000),
            'end_time': time(6, 51, 19, 403000),
            'start_measured_depth': 0.0,
            'end_measured_depth': 0.0,
            'category': JobCategory.DRILLING,
            'p': YesNo.Y,
            'npt': NPT.NP,
            'code': OperationCode.RIG_UP_TEAR_DOWN,
            'operation': 'tulisan'
        }
    ],
    'bit_records': [
        {
            'bit_size': 0.0,
            'bit_number': 0,
            'bit_run': 0,
            'manufacturer': 'string',
            'iadc_code': 'string',
            'jets': 'string',
            'serial': 'string',
            'depth_out': 0.0,
            'depth_in': 0.0,
            'meterage': 0.0,
            'bit_hours': 0.0,
            'nozzels': 0.0,
            'dull_grade': 'string'
        }
    ],
    'bottom_hole_assemblies': [
        {
            'bha_number': 0,
            'bha_run': 0,
            'components': [
                {
                    'component': BHAComponentType.BUMPER_SUB,
                    'outer_diameter': 0.0,
                    'length': 0.0
                }
            ]
        },
        {
            'bha_number': 0,
            'bha_run': 0,
            'components': [
                {
                    'component': BHAComponentType.BUMPER_SUB,
                    'outer_diameter': 0.0,
                    'length': 0.0
                }
            ]
        }
    ],
    'drilling_fluids': [
        {
            'mud_type': MudType.LIQUID,
            'time': time(4, 51, 19, 404000),
            'mw_in': 0.0,
            'mw_out': 0.0,
            'temp_in': 0.0,
            'temp_out': 0.0,
            'pres_grad': 0.0,
            'visc': 0.0,
            'pv': 0.0,
            'yp': 0.0,
            'gels_10_sec': 0.0,
            'gels_10_min': 0.0,
            'fluid_loss': 0.0,
            'ph': 0.0,
            'solids': 0.0,
            'sand': 0.0,
            'water': 0.0,
            'oil': 0.0,
            'hgs': 0.0,
            'lgs': 0.0,
            'ltlp': 0.0,
            'hthp': 0.0,
            'cake': 0.0,
            'e_stb': 0.0,
            'pf': 0.0,
            'mf': 0.0,
            'pm': 0.0,
            'ecd': 0.0
        }
    ],
    "mud_additives": [
        {
        "mud_additive_type": "string",
        "amount": 0
        }
    ],
    "bulk_materials": [
        {
        "material_type": "string",
        "material_name": "string",
        "material_uom": "string",
        "received": 0,
        "consumed": 0,
        "returned": 0,
        "adjust": 0,
        "ending": 0
        }
    ],
    "directional_surveys": [
        {
        "measured_depth": 0,
        "inclination": 0,
        "azimuth": 0
        }
    ],
    "pumps": [
        {
        "slow_speed": "Y",
        "circulate": 0,
        "strokes": 0,
        "pressure": 0,
        "liner_size": 0,
        "efficiency": 0
        }
    ],
    'weather': {
        'temperature_high': 0.0,
        'temperature_low': 0.0,
        'chill_factor': 0.0,
        'wind_speed': 0.0,
        'wind_direction': 0.0,
        'barometric_pressure': 0.0,
        'wave_height': 0.0,
        'wave_current_speed': 0.0,
        'road_condition': 'string',
        'visibility': 'string'
    },
    'report_date': date(2024, 6, 7),
    'operator': 'KKKS146',
    'well_name': 'WELL0118',
    'job_type': 'WELLSERVICE',
    'field': 'West SIS-A',
    'latitude': Decimal('-1.679040865'),
    'longitude': Decimal('117.064261017'),
    'environment': 'LAND',
    'spud_date': datetime(2024, 11, 16, 0, 0),
    'kb_elev': Decimal('0.00000'),
    'afe_number': '-',
    'planned_days': 214,
    'days_from_spud': -162
}

# %%
from decimal import Decimal
from datetime import date, time, datetime
from enum import Enum


def process_value(value):
    if isinstance(value, Enum):
        return value.value
    elif isinstance(value, datetime):
        return value.date()
    elif isinstance(value, time):
        return time(value.hour, value.minute)
    elif isinstance(value, list):
        return [process_value(item) for item in value]
    elif isinstance(value, dict):
        return {key: process_value(val) for key, val in value.items()}
    else:
        return value

# Process the data dictionary
for key, value in data.items():
    data[key] = process_value(value)

if 'time_breakdowns' in data.keys() and data['time_breakdowns'] != None:
    for dict_ in data['time_breakdowns']:

        datetime1 = datetime.combine(date.min, dict_['start_time'])
        datetime2 = datetime.combine(date.min, dict_['end_time'])

        # Calculate the difference
        time_difference = datetime2 - datetime1

        # Convert the difference to total seconds
        total_seconds = time_difference.total_seconds()


        hours = int(total_seconds // 3600)
        minutes = int((total_seconds % 3600) // 60)

        # Create a time object for the difference
        time_difference_obj = time(hours, minutes)

        dict_['elapsed'] = time_difference_obj.strftime("%H:%M")
        dict_['start_time'] = dict_['start_time'].strftime("%H:%M")
        dict_['end_time'] = dict_['end_time'].strftime("%H:%M")


data
# Out:
# {'avg_wob': 0.0,
#  'avg_rop': 0.0,
#  'avg_rpm': 0.0,
#  'torque': 0.0,
#  'stand_pipe_pressure': 0.0,
#  'flow_rate': 0.0,
#  'string_weight': 0.0,
#  'rotating_weight': 0.0,
#  'total_drilling_time': 0.0,
#  'circulating_pressure': 0.0,
#  'daily_cost': 0.0,
#  'daily_mud_cost': 0.0,
#  'day_supervisor': 'string',
#  'night_supervisor': 'string',
#  'engineer': 'string',
#  'geologist': 'string',
#  'day_summary': 'string',
#  'day_forecast': 'string',
#  'last_size': 0.0,
#  'set_md': 0.0,
#  'next_size': 0.0,
#  'next_set_md': 0.0,
#  'last_lot_emw': 0.0,
#  'tol': 0.0,
#  'start_mud_volume': 0.0,
#  'lost_surface_mud_volume': 0.0,
#  'lost_dh_mud_volume': 0.0,
#  'dumped_mud_volume': 0.0,
#  'built_mud_volume': 0.0,
#  'ending_mud_volume': 0.0,
#  'max_gas': 0.0,
#  'conn_gas': 0.0,
#  'trip_gas': 0.0,
#  'back_gas': 0.0,
#  'annular_velocity': 0.0,
#  'pb': 0.0,
#  'sys_hhp': 0.0,
#  'hhpb': 0.0,
#  'hsi': 0.0,
#  'percent_psib': 0.0,
#  'jet_velocity': 0.0,
# ...

# %%
from jinja2 import Template

merged_data = data

# Baca template HTML
with open("/home/linuxelementary/Documents/skkproyek/backendSKKMigas/DOR-format jaga-jaga.htm", "r") as file:
    html_template = file.read()

# Render template menggunakan data gabungan
template = Template(html_template)
html_output = template.render(merged_data)

# Simpan output ke file baru
output_path = "/home/linuxelementary/Documents/DOR (Replaced).htm"
with open(output_path, "w") as file:
    file.write(html_output)

print(f"Template berhasil diisi dan disimpan ke {output_path}")
# Out:
# Template berhasil diisi dan disimpan ke /home/linuxelementary/Documents/DOR (Replaced).htm

# %%
from datetime import datetime

# Contoh objek datetime lengkap
dt = datetime(2024, 11, 16, 4, 51, 19, 403000)

# Set detik dan mikrodetik menjadi 0
dt_without_seconds = dt.replace(second=0, microsecond=0)

print(dt_without_seconds)  # Output: 2024-11-16 04:51:00
print(type(dt_without_seconds))  # Output: <class 'datetime.datetime'>
# Out:
# 2024-11-16 04:51:00
# <class 'datetime.datetime'>

# %%
if np.isnan(df['KolomNull'].unique()).any():
    print('Masuk')
# Out:
# Masuk

# %%
import pandas as pd
import numpy as np

# Membuat DataFrame
data = {
    "Kolom1": [1, 2, 3, 4, 5],
    "Kolom2": ["A", "B", "C", "D", "E"],
    "Kolom3": ["A", "A", "A", "A", "A"],
    "KolomNull": [np.nan, np.nan, np.nan, np.nan, 2.5],
    "KolomNull2": [np.nan, np.nan, np.nan, np.nan, np.nan]# Kolom dengan nilai null
}

df = pd.DataFrame(data)

idx_check_null = df.isnull().all().to_numpy()

if True in idx_check_null:
    idx_true = np.where(True==idx_check_null)[0]
    df.drop(df.columns[idx_true],axis=1,inplace=True)

idx_check_non_unique = [True if len(df[col].unique()) == 1 else False for col in df.columns]

if True in idx_check_non_unique:
    idx_true = np.where(True==np.array(idx_check_non_unique))[0]
    df.drop(df.columns[idx_true],axis=1,inplace=True)

# %%
import pandas as pd

# %%
df = pd.read_excel('/home/linuxelementary/Documents/Xell_ujicoba.xlsx')

# %%
alert_delete = ''

data = {
    "Kolom1": [1, 2, 3, 4, 5],
    "Kolom2": ["A", "B", "C", "D", "E"],
    "Kolom3": ["A", "A", "A", "A", "A"],
    "KolomNull": [np.nan, np.nan, np.nan, np.nan, 2.5],
    "KolomNull2": [np.nan, np.nan, np.nan, np.nan, np.nan]# Kolom dengan nilai null
}

df = pd.DataFrame(data)

idx_check_null = df.isnull().all().to_numpy()

if True in idx_check_null:
    idx_true = np.where(True==idx_check_null)[0]
    df.drop(df.columns[idx_true],axis=1,inplace=True)
    
    # alert_delete = dmc.Alert(
    #         'Some Column Deleted Because Null or Doesnt have Uniqueness',
    #         color="orange",
    #         variant="filled",
    #         withCloseButton=True
    #         )

idx_check_non_unique = [True if len(df[col].unique()) == 1 or (len(df[col].unique()) == 2 and pd.isna(df['KolomNull'].unique()).any()) else False for col in df.columns]

if True in idx_check_non_unique:
    idx_true = np.where(True==np.array(idx_check_non_unique))[0]
    df.drop(df.columns[idx_true],axis=1,inplace=True)


    # alert_delete = dmc.Alert(
    #         'Some Column Deleted Because Null or Doesnt have Uniqueness',
    #         color="orange",
    #         variant="filled",
    #         withCloseButton=True
    #         )


    # alert_delete = dmc.Alert(
    #         'Some Column Deleted Because Null or Doesnt have Uniqueness',
    #         color="orange",
    #         variant="filled",
    #         withCloseButton=True
    #         )

df
# Out:
#    Kolom1 Kolom2
# 0       1      A
# 1       2      B
# 2       3      C
# 3       4      D
# 4       5      E

# %%
colum = df.columns

for col in colum:
    print(len(df[col].unique()) == 2)
# Out:
# False
# False
# True

# %%
np.isnan(df['Kolom2'].unique()).any()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 np.isnan(df['Kolom2'].unique()).any()
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
idx_lain = [True if len(df[col].unique()) == 2 and pd.isna(df['KolomNull'].unique()).any() else False for col in df.columns]
idx_lain
# Out:
# [False, False, True]

# %%
from dash_pydantic_form import ModelForm, fields
from pydantic import BaseModel, Field, ValidationError, root_validator
from typing import Optional, Literal, List

# %%
class WellPressure(BaseModel):
    
    uwi: Optional[str] = Field(default=None, serialization_alias='Uwi')
    source: Optional[str] = Field(default=None, serialization_alias='Source')
    pressure_obs_no: Optional[int] = Field(default=None, serialization_alias='Pressure Obs No')
    
    #ini literal kah?
    active_ind: Optional[str] = Field(default=None, serialization_alias='Active Ind')
    
    assigned_field: Optional[str] = Field(default=None, serialization_alias='Assigned Field')
    base_depth: Optional[float] = Field(default=None, serialization_alias='Base Depth')
    base_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Base Depth Ouom')
    base_strat_unit_id: Optional[str] = Field(default=None, serialization_alias='Base Strat Unit Id')
    effective_date: Optional[date] = Field(default=None, serialization_alias='Effective Date')
    event_obs_no: Optional[int] = Field(default=None, serialization_alias='Event Obs No')
    event_source: Optional[str] = Field(default=None, serialization_alias='Event Source')
    expiry_date: Optional[date] = Field(default=None, serialization_alias='Expiry Date')
    flow_casing_pressure: Optional[float] = Field(default=None, serialization_alias='Flow Casing Pressure')
    flow_casing_pressure_ouom: Optional[str] = Field(default=None, serialization_alias='Flow Casing Pressure Ouom')
    flow_tubing_pressure: Optional[float] = Field(default=None, serialization_alias='Flow Tubing Pressure')
    flow_tubing_pressure_ouom: Optional[str] = Field(default=None, serialization_alias='Flow Tubing Pressure Ouom')
    init_reservoir_pressure: Optional[float] = Field(default=None, serialization_alias='Init Reservoir Pressure')
    init_reservoir_press_ouom: Optional[str] = Field(default=None, serialization_alias='Init Reservoir Press Ouom')
    pool_datum: Optional[str] = Field(default=None, serialization_alias='Pool Datum')
    pool_datum_depth: Optional[float] = Field(default=None, serialization_alias='Pool Datum Depth')
    pool_datum_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Pool Datum Depth Ouom')
    pool_id: Optional[str] = Field(default=None, serialization_alias='Pool Id')
    ppdm_guid: Optional[str] = Field(default=None, serialization_alias='Ppdm Guid')
    prod_string_id: Optional[str] = Field(default=None, serialization_alias='Prod String Id')
    prod_string_source: Optional[str] = Field(default=None, serialization_alias='Prod String Source')
    pr_str_form_obs_no: Optional[int] = Field(default=None, serialization_alias='Pr Str Form Obs No')
    remark: Optional[str] = Field(default=None, serialization_alias='Remark')
    shutin_casing_pressure: Optional[float] = Field(default=None, serialization_alias='Shutin Casing Pressure')
    suhtin_casing_pressure_ouom: Optional[str] = Field(default=None, serialization_alias='Suhtin Casing Pressure Ouom')
    shutin_tubing_pressure: Optional[float] = Field(default=None, serialization_alias='Shutin Tubing Pressure')
    shutin_tubing_pressure_ouom: Optional[str] = Field(default=None, serialization_alias='Shutin Tubing Pressure Ouom')
    strat_name_set_id: Optional[str] = Field(default=None, serialization_alias='Strat Name Set Id')
    top_depth: Optional[float] = Field(default=None, serialization_alias='Top Depth')
    top_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Top Depth Ouom')
    top_strat_unit_id: Optional[str] = Field(default=None, serialization_alias='Top Strat Unit Id')
    well_datum_depth: Optional[float] = Field(default=None, serialization_alias='Well Datum Depth')
    well_datum_ouom: Optional[str] = Field(default=None, serialization_alias='Well Datum Ouom')
    
    #ini di excel double hapus saja kah?
    top_strat_unit_id_1: Optional[str] = Field(default=None, serialization_alias='Top Strat Unit Id')
    well_datum_depth_1: Optional[float] = Field(default=None, serialization_alias='Well Datum Depth')
    well_datum_ouom_1: Optional[str] = Field(default=None, serialization_alias='Well Datum Ouom')
    
    
    well_test_num: Optional[str] = Field(default=None, serialization_alias='Well Test Num')
    well_test_run_num: Optional[str] = Field(default=None, serialization_alias='Well Test Run Num')
    well_test_source: Optional[str] = Field(default=None, serialization_alias='Well Test Source')
    
    #ini literal kah?
    well_test_type: Optional[str] = Field(default=None, serialization_alias='Well Test Type')
    
    row_changed_by: Optional[str] = Field(default=None, serialization_alias='Row Changed By')
    row_changed_date: Optional[date] = Field(default=None, serialization_alias='Row Changed Date')
    row_created_by: Optional[str] = Field(default=None, serialization_alias='Row Created By')
    row_created_date: Optional[date] = Field(default=None, serialization_alias='Row Created Date')
    row_effective_date: Optional[date] = Field(default=None, serialization_alias='Row Effective Date')
    row_expiry_date: Optional[date] = Field(default=None, serialization_alias='Row Expiry Date')
    row_quality: Optional[str] = Field(default=None, serialization_alias='Row Quality')

# %%
class WellLog(BaseModel):

    uwi: Optional[str] = Field(default=None, serialization_alias='Uwi')
    well_log_id: Optional[str] = Field(default=None, serialization_alias='Well Log Id')
    source: Optional[str] = Field(default=None, serialization_alias='Source')
    acquired_for_ba_id: Optional[str] = Field(default=None, serialization_alias='Acquired For Ba Id')
    
    #ini Literal kah?
    active_ind: Optional[str] = Field(default=None, serialization_alias='Active Ind')
    
    
    base_depth: Optional[float] = Field(default=None, serialization_alias='Base Depth')
    base_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Base Depth Ouom')
    
    #ini Literal kah?
    bypass_ind: Optional[str] = Field(default=None, serialization_alias='Bypass Ind')
    cased_hole_ind: Optional[str] = Field(default=None, serialization_alias='Cased Hole Ind')
    composite_ind: Optional[str] = Field(default=None, serialization_alias='Composite Ind')
    depth_type: Optional[str] = Field(default=None, serialization_alias='Depth Type')
    
    dictionary_id: Optional[str] = Field(default=None, serialization_alias='Dictionary Id')
    effective_date: Optional[date] = Field(default=None, serialization_alias='Effective Date')
    expiry_date: Optional[date] = Field(default=None, serialization_alias='Expiry Date')
    log_job_id: Optional[str] = Field(default=None, serialization_alias='Log Job Id')
    log_job_source: Optional[str] = Field(default=None, serialization_alias='Log Job Source')
    log_ref_num: Optional[str] = Field(default=None, serialization_alias='Log Ref Num')
    log_title: Optional[str] = Field(default=None, serialization_alias='Log Title')
    log_tool_pass_no: Optional[int] = Field(default=None, serialization_alias='Log Tool Pass No')
    
    #ini Literal kah?
    mwd_ind: Optional[str] = Field(default=None, serialization_alias='Mwd Ind')
    
    ppdm_guid: Optional[str] = Field(default=None, serialization_alias='Ppdm Guid')
    remark: Optional[str] = Field(default=None, serialization_alias='Remark')
    top_depth: Optional[float] = Field(default=None, serialization_alias='Top Depth')
    top_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Top Depth Ouom')
    trip_obs_no: Optional[int] = Field(default=None, serialization_alias='Trip Obs No')
    row_changed_by: Optional[str] = Field(default=None, serialization_alias='Row Changed By')
    row_changed_date: Optional[date] = Field(default=None, serialization_alias='Row Changed Date')
    row_created_by: Optional[str] = Field(default=None, serialization_alias='Row Created By')
    row_created_date: Optional[date] = Field(default=None, serialization_alias='Row Created Date')
    row_effective_date: Optional[date] = Field(default=None, serialization_alias='Row Effective Date')
    row_expiry_date: Optional[date] = Field(default=None, serialization_alias='Row Expiry Date')
    row_quality: Optional[str] = Field(default=None, serialization_alias='Row Quality')

# %%
class WellEquipment(BaseModel):
    uwi: Optional[str] = Field(default=None, serialization_alias='Uwi')
    source: Optional[str] = Field(default=None, serialization_alias='Source')
    equipment_id: Optional[str] = Field(default=None, serialization_alias='Equipment Id')
    equip_obs_no: Optional[int] = Field(default=None, serialization_alias='Equip Obs No')
    
    #ini Literal kah?
    active_ind: Optional[str] = Field(default=None, serialization_alias='Active Ind')
    
    effective_date: Optional[date] = Field(default=None, serialization_alias='Effective Date')
    expiry_date: Optional[date] = Field(default=None, serialization_alias='Expiry Date')
    install_base_depth: Optional[float] = Field(default=None, serialization_alias='Install Base Depth')
    install_base_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Install Base Depth Ouom')
    install_date: Optional[date] = Field(default=None, serialization_alias='Install Date')
    install_seq_no: Optional[int] = Field(default=None, serialization_alias='Install Seq No')
    install_top_depth: Optional[float] = Field(default=None, serialization_alias='Install Top Depth')
    install_top_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Install Top Depth Ouom')
    parent_equipment_id: Optional[str] = Field(default=None, serialization_alias='Parent Equipment Id')
    ppdm_guid: Optional[str] = Field(default=None, serialization_alias='Ppdm Guid')
    remark: Optional[str] = Field(default=None, serialization_alias='Remark')
    removal_date: Optional[date] = Field(default=None, serialization_alias='Removal Date')
    string_id: Optional[str] = Field(default=None, serialization_alias='String Id')
    string_source: Optional[str] = Field(default=None, serialization_alias='String Source')
    row_changed_by: Optional[str] = Field(default=None, serialization_alias='Row Changed By')
    row_changed_date: Optional[date] = Field(default=None, serialization_alias='Row Changed Date')
    row_created_by: Optional[str] = Field(default=None, serialization_alias='Row Created By')
    row_created_date: Optional[date] = Field(default=None, serialization_alias='Row Created Date')
    row_effective_date: Optional[date] = Field(default=None, serialization_alias='Row Effective Date')
    row_expiry_date: Optional[date] = Field(default=None, serialization_alias='Row Expiry Date')
    row_quality: Optional[str] = Field(default=None, serialization_alias='Row Quality')

# %%
class WellCompletion(BaseModel):
    
    uwi: Optional[str] = Field(default=None, serialization_alias='Uwi')
    source: Optional[str] = Field(default=None, serialization_alias='Source')
    completion_obs_no: Optional[int] = Field(default=None, serialization_alias='Completion Obs No')
    active_ind: Optional[str] = Field(default=None, serialization_alias='Active Ind')
    base_depth: Optional[float] = Field(default=None, serialization_alias='Base Depth')
    base_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Base Depth Ouom')
    base_strat_unit_id: Optional[str] = Field(default=None, serialization_alias='Base Strat Unit Id')
    completion_date: Optional[date] = Field(default=None, serialization_alias='Completion Date')
    completion_method: Optional[str] = Field(default=None, serialization_alias='Completion Method')
    completion_strat_unit_id: Optional[str] = Field(default=None, serialization_alias='Completion Strat Unit Id')
    
    #ini Literal Kah?
    completion_type: Optional[str] = Field(default=None, serialization_alias='Completion Type')
    
    
    effective_date: Optional[date] = Field(default=None, serialization_alias='Effective Date')
    expiry_date: Optional[date] = Field(default=None, serialization_alias='Expiry Date')
    ppdm_guid: Optional[str] = Field(default=None, serialization_alias='Ppdm Guid')
    remark: Optional[str] = Field(default=None, serialization_alias='Remark')
    strat_name_set_id: Optional[str] = Field(default=None, serialization_alias='Strat Name Set Id')
    top_depth: Optional[float] = Field(default=None, serialization_alias='Top Depth')
    top_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Top Depth Ouom')
    top_strat_unit_id: Optional[str] = Field(default=None, serialization_alias='Top Strat Unit Id')
    row_changed_by: Optional[str] = Field(default=None, serialization_alias='Row Changed By')
    row_changed_date: Optional[date] = Field(default=None, serialization_alias='Row Changed Date')
    row_created_by: Optional[str] = Field(default=None, serialization_alias='Row Created By')
    row_created_date: Optional[date] = Field(default=None, serialization_alias='Row Created Date')
    row_effective_date: Optional[date] = Field(default=None, serialization_alias='Row Effective Date')
    row_expiry_date: Optional[date] = Field(default=None, serialization_alias='Row Expiry Date')
    row_quality: Optional[str] = Field(default=None, serialization_alias='Row Quality')

# %%
class WellCement(BaseModel):
    
    uwi: Optional[str] = Field(default=None, serialization_alias='Uwi')
    well_tube_source: Optional[str] = Field(default=None, serialization_alias='Well Tube Source')
    
    #ini Literal kah soalnya di pgadmin varchar
    tubing_type: Optional[str] = Field(default=None, serialization_alias='Tubing Type')
    
    tubing_obs_no: Optional[int] = Field(default=None, serialization_alias='Tubing Obs No')
    cement_obs_no : Optional[int] = Field(default=None, serialization_alias='Cement Obs No')
    active_ind: Optional[str] = Field(default=None, serialization_alias='Active Ind')
    cement_amount: Optional[float] = Field(default=None, serialization_alias='Cement Amount')
    cement_amount_ouom: Optional[str] = Field(default=None, serialization_alias='Cement Amount Ouom')
    cement_amount_uom: Optional[str] = Field(default=None, serialization_alias='Cement Amount Uom')
    cement_ba_id: Optional[str] = Field(default=None, serialization_alias='Cement Ba Id')
    
    #ini juga
    cement_type: Optional[str] = Field(default=None, serialization_alias='Cement Type')
    
    
    effective_date: Optional[date] = Field(default=None, serialization_alias='Effective Date')
    expiry_date: Optional[date] = Field(default=None, serialization_alias='Expiry Date')
    perforation_base_depth: Optional[float] = Field(default=None, serialization_alias='Perforation Base Depth')
    perforation_base_depth_ouuom: Optional[str] = Field(default=None, serialization_alias='Perforation Base Depth Ouuom')
    perforation_count: Optional[int] = Field(default=None, serialization_alias='Perforation Count')
    perforation_per_uom: Optional[str] = Field(default=None, serialization_alias='Perforation Per Uom')
    perforation_top_depth: Optional[float] = Field(default=None, serialization_alias='Perforation Top Depth')
    perforation_top_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Perforation Top Depth Ouom')
    ppdm_guid: Optional[str] = Field(default=None, serialization_alias='Ppdm Guid')
    
    #ini juga
    recement_ind: Optional[str] = Field(default=None, serialization_alias='Recement Ind')
    
    remark: Optional[str] = Field(default=None, serialization_alias='Remark')
    source: Optional[str] = Field(default=None, serialization_alias='Source')
    stage_no: Optional[int] = Field(default=None, serialization_alias='Stage No')
    row_changed_by: Optional[str] = Field(default=None, serialization_alias='Row Changed By')
    row_changed_date: Optional[str] = Field(default=None, serialization_alias='Row Changed Date')
    row_created_by: Optional[str] = Field(default=None, serialization_alias='Row Created By')
    row_created_date: Optional[date] = Field(default=None, serialization_alias='Row Created Date')
    row_effective_date: Optional[date] = Field(default=None, serialization_alias='Row Effective Date')
    row_expiry_date: Optional[date] = Field(default=None, serialization_alias='Row Expiry Date')
    row_quality: Optional[str] = Field(default=None, serialization_alias='Row Quality')

# %%
class WellTubular(BaseModel):

    uwi: Optional[str] = Field(default=None, serialization_alias='Uwi')
    source: Optional[str] = Field(default=None, serialization_alias='Source')
    
    #ini literal kah?
    tubing_type: Optional[str] = Field(default=None, serialization_alias='Tubing Type')
    
    
    tubing_obs_no: Optional[int] = Field(default=None, serialization_alias='Tubing Obs No')
    
    #ini juga
    active_ind: Optional[str] = Field(default=None, serialization_alias='Active Ind')
    
    base_depth: Optional[float] = Field(default=None, serialization_alias='Base Depth')
    base_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Base Depth Ouom')
    base_strat_unit_id: Optional[str] = Field(default=None, serialization_alias='Base Strat Unit Id')
    cat_equip_id: Optional[str] = Field(default=None, serialization_alias='Cat Equip Id')
    
    #ini juga
    collar_type: Optional[str] = Field(default=None, serialization_alias='Collar Type')
    coupling_type: Optional[str] = Field(default=None, serialization_alias='Coupling Type')
    
    effective_date: Optional[date] = Field(default=None, serialization_alias='Effective Date')
    equipment_id: Optional[str] = Field(default=None, serialization_alias='Equipment Id')
    expiry_date: Optional[date] = Field(default=None, serialization_alias='Expiry Date')
    hole_size: Optional[float] = Field(default=None, serialization_alias='Hole Size')
    hole_size_ouom: Optional[str] = Field(default=None, serialization_alias='Hole Size Ouom')
    hung_top_depth: Optional[float] = Field(default=None, serialization_alias='Hung Top Depth')
    hung_top_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Hung Top Depth Ouom')
    inside_diameter: Optional[float] = Field(default=None, serialization_alias='Inside Diameter')
    inside_diameter_ouom: Optional[str] = Field(default=None, serialization_alias='Inside Diameter Ouom')
    joint_count: Optional[int] = Field(default=None, serialization_alias='Joint Count')
    left_in_hole_length: Optional[float] = Field(default=None, serialization_alias='Left In Hole Length')
    left_in_hole_length_ouom: Optional[str] = Field(default=None, serialization_alias='Left In Hole Length Ouom')
    liner_type: Optional[str] = Field(default=None, serialization_alias='Liner Type')
    manufacturer_ba_id: Optional[str] = Field(default=None, serialization_alias='Manufacturer Ba Id')
    
    #ini juga?
    mixed_string_ind: Optional[str] = Field(default=None, serialization_alias='Mixed String Ind')
    observation_date: Optional[date] = Field(default=None, serialization_alias='Observation Date')
    outside_diameter: Optional[float] = Field(default=None, serialization_alias='Outside Diameter')
    outside_diameter_desc: Optional[str] = Field(default=None, serialization_alias='Outside Diameter Desc')
    outside_diameter_ouom: Optional[str] = Field(default=None, serialization_alias='Outside Diameter Ouom')
    packer_set_depth: Optional[float] = Field(default=None, serialization_alias='Packer Set Depth')
    packer_set_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Packer Set Depth Ouom')
    period_obs_no: Optional[int] = Field(default=None, serialization_alias='Period Obs No')
    ppdm_guid: Optional[str] = Field(default=None, serialization_alias='Ppdm Guid')
    pulled_length: Optional[float] = Field(default=None, serialization_alias='Pulled Length')
    pulled_length_ouom: Optional[str] = Field(default=None, serialization_alias='Pulled Length Ouom')
    remark: Optional[str] = Field(default=None, serialization_alias='Remark')
    reported_base_tvd: Optional[float] = Field(default=None, serialization_alias='Reported Base Tvd')
    reported_base_tvd_ouom: Optional[str] = Field(default=None, serialization_alias='Reported Base Tvd Ouom')
    reported_top_tvd: Optional[float] = Field(default=None, serialization_alias='Reported Top Tvd')
    report_top_tvd_ouom: Optional[str] = Field(default=None, serialization_alias='Report Top Tvd Ouom')
    sea_floor_penetration: Optional[float] = Field(default=None, serialization_alias='Sea Floor Penetration')
    sea_floor_penetration_ouom: Optional[str] = Field(default=None, serialization_alias='Sea Floor Penetration Ouom')
    shoe_depth: Optional[float] = Field(default=None, serialization_alias='Shoe Depth')
    shoe_depth_ouom: Optional[str] = Field(default=None, serialization_alias='Shoe Depth Ouom')
    steel_spec: Optional[str] = Field(default=None, serialization_alias='Steel Spec')
    strat_name_set_id: Optional[str] = Field(default=None, serialization_alias='Strat Name Set Id')
    top_strat_unit_id: Optional[str] = Field(default=None, serialization_alias='Top Strat Unit Id')
    torque: Optional[float] = Field(default=None, serialization_alias='Torque')
    torque_ouom: Optional[str] = Field(default=None, serialization_alias='Torque Ouom')
    tubing_density: Optional[float] = Field(default=None, serialization_alias='Tubing Density')
    tubing_density_ouom: Optional[str] = Field(default=None, serialization_alias='Tubing Density Ouom')
    tubing_grade: Optional[str] = Field(default=None, serialization_alias='Tubing Grade')
    tubing_strength: Optional[float] = Field(default=None, serialization_alias='Tubing Strength')
    tubing_strength_ouom: Optional[str] = Field(default=None, serialization_alias='Tubing Strength Ouom')
    tubing_weight: Optional[float] = Field(default=None, serialization_alias='Tubing Weight')
    tubing_weight_ouom: Optional[str] = Field(default=None, serialization_alias='Tubing Weight Ouom')
    row_changed_by: Optional[str] = Field(default=None, serialization_alias='Row Changed By')
    row_changed_date: Optional[date] = Field(default=None, serialization_alias='Row Changed Date')
    row_created_by: Optional[str] = Field(default=None, serialization_alias='Row Created By')
    row_created_date: Optional[date] = Field(default=None, serialization_alias='Row Created Date')
    row_effective_date: Optional[date] = Field(default=None, serialization_alias='Row Effective Date')
    row_expiry_date: Optional[date] = Field(default=None, serialization_alias='Row Expiry Date')
    row_quality: Optional[str] = Field(default=None, serialization_alias='Row Quality')

# %%
class WellMandatoryBase(BaseModel):
    
    unit_type: Optional[UnitType] = Field(default=None, serialization_alias='Unit Type') # type: ignore
        
    # Well Status and Classification
    well_level_type: Optional[Literal[tuple(const.well_level_type)]] = Field(default=None, serialization_alias='Well Level Type') # type: ignore
    well_class: Optional[Literal[tuple(const.well_class)]] = Field(default=None, serialization_alias='Well Class') # type: ignore
    well_profile_type: Optional[Literal[tuple(const.well_profile_type)]] = Field(default=None, serialization_alias='Well Profile Type') # type: ignore
    environment_type: Optional[Literal[tuple(const.environment_type)]] = Field(default=None, serialization_alias='Environment Type') # type: ignore
    
    # Coordinates
    surface_longitude: Optional[float] = Field(default=None, serialization_alias='Surface Longitude')
    surface_latitude: Optional[float] = Field(default=None, serialization_alias='Surface Latitude')
    bottom_hole_longitude: Optional[float] = Field(default=None, serialization_alias='Bottom Hole Longitude')
    bottom_hole_latitude: Optional[float] = Field(default=None, serialization_alias='Bottom Hole Latitude')
    
    # Key Dates
    spud_date: Optional[date] = Field(default=None, serialization_alias='Spud Date')
    final_drill_date: Optional[date] = Field(default=None, serialization_alias='Final Drill Date')
    completion_date: Optional[date] = Field(default=None, serialization_alias='Completion Date')
    abandonment_date: Optional[date] = Field(default=None, serialization_alias='Abandonment Date')
    rig_on_site_date: Optional[date] = Field(default=None, serialization_alias='Rig On-Site Date')
    rig_release_date: Optional[date] = Field(default=None, serialization_alias='Rig Release Date')

    maximum_inclination: Optional[float] = Field(default=None, serialization_alias='Maximum Inclination')
    azimuth: Optional[float] = Field(default=None, serialization_alias='Azimuth')
    hydrocarbon_target: Optional[Literal[tuple(const.hydrocarbon_target)]] = Field(default=None, serialization_alias='Hydrocarbon Target') # type: ignore
    kick_off_point: Optional[float] = Field(default=None, serialization_alias='Kick Off Point')
    
    # Elevations
    difference_lat_msl: Optional[float] = Field(default=None, serialization_alias='Difference Lat MSL')
    subsea_elev_ref_type: Optional[Literal[tuple(const.subsea_elev_ref_type)]] = Field(default=None, serialization_alias='Subsea Elev Ref Type') # type: ignore
    elev_ref_datum: Optional[Literal[tuple(const.elev_ref_datum)]] = Field(default=None, serialization_alias='Elev Ref Datum') # type: ignore
    
    rotary_table_elev: Optional[float] = Field(default=None, serialization_alias='Rotary Table Elev')
    kb_elev: Optional[float] = Field(default=None, serialization_alias='KB Elev')
    derrick_floor_elev: Optional[float] = Field(default=None, serialization_alias='Derrick Floor Elev')
    ground_elev: Optional[float] = Field(default=None, serialization_alias='Ground Elev')
    ground_elev_type: Optional[Literal[tuple(const.ground_elev_type)]] = Field(default=None, serialization_alias='Ground Elev Type') # type: ignore
    
    # Depths
    base_depth: Optional[float] = Field(default=None, serialization_alias='Base Depth')
    water_depth: Optional[float] = Field(default=None, serialization_alias='Water Depth')
    water_depth_datum: Optional[Literal[tuple(const.water_depth_datum)]] = Field(default=None, serialization_alias='Water Depth Datum') # type: ignore
    deepest_depth: Optional[float] = Field(default=None, serialization_alias='Deepest Depth')
    depth_datum: Optional[str] = Field(default=None, serialization_alias='Depth Datum')
    depth_datum_elev: Optional[float] = Field(default=None, serialization_alias='Depth Datum Elev')
    drill_td: Optional[float] = Field(default=None, serialization_alias='Drill TD')
    top_depth: Optional[float] = Field(default=None, serialization_alias='Top Depth')
    maximum_tvd: Optional[float] = Field(default=None, serialization_alias='Maximum TVD')
    final_md: Optional[float] = Field(default=None, serialization_alias='Final MD')
    plugback_depth: Optional[float] = Field(default=None, serialization_alias='Plugback Depth')
    whipstock_depth: Optional[float] = Field(default=None, serialization_alias='Whipstock Depth')
    
    # Other
    water_acoustic_vel: Optional[float] = Field(default=None, serialization_alias='Water Acoustic Vel')
    net_pay: Optional[float] = Field(default=None, serialization_alias='Net Pay')

# %%
class WellArea(BaseModel):
    
    uwi: Optional[str] = Field(default=None, serialization_alias='Uwi')
    source: Optional[str] = Field(default=None, serialization_alias='Source')
    area_id: Optional[str] = Field(default=None, serialization_alias='Area Id')
    
    #ini literal
    area_type: Optional[str] = Field(default=None, serialization_alias='Area Type')
    active_ind: Optional[str] = Field(default=None, serialization_alias='Active Ind')
    
    effective_date: Optional[date] = Field(default=None, serialization_alias='Effective Date')
    expiry_date: Optional[date] = Field(default=None, serialization_alias='Expiry Date')
    ppdm_guid: Optional[str] = Field(default=None, serialization_alias='Ppdm Guid')
    remark: Optional[str] = Field(default=None, serialization_alias='Remark')
    row_changed_by: Optional[str] = Field(default=None, serialization_alias='Row Changed By')
    row_changed_date: Optional[date] = Field(default=None, serialization_alias='Row Changed Date')
    row_created_by: Optional[str] = Field(default=None, serialization_alias='Row Created By')
    row_created_date: Optional[date] = Field(default=None, serialization_alias='Row Created Date')
    row_effective_date: Optional[date] = Field(default=None, serialization_alias='Row Effective Date')
    row_expiry_date: Optional[date] = Field(default=None, serialization_alias='Row Expiry Date')
    row_quality: Optional[str] = Field(default=None, serialization_alias='Row Quality')

# %%
df = pd.read_excel('/home/linuxelementary/Downloads/Apdps schema/WELL_AREA.xlsx')

# %%
df.columns
# Out:
# Index(['UWI', 'SOURCE', 'AREA_ID', 'AREA_TYPE', 'ACTIVE_IND', 'EFFECTIVE_DATE',
#        'EXPIRY_DATE', 'PPDM_GUID', 'REMARK', 'ROW_CHANGED_BY',
#        'ROW_CHANGED_DATE', 'ROW_CREATED_BY', 'ROW_CREATED_DATE',
#        'ROW_EFFECTIVE_DATE', 'ROW_EXPIRY_DATE', 'ROW_QUALITY'],
#       dtype='object')

# %% [markdown]
# {% if components%}
# 	{% if bottom_hole_assemblies[0].components|length > bottom_hole_assemblies[1].components|length}
# 		{% set total_component = bottom_hole_assemblies[0].components|length%}
# 	{% else %}
# 		{% set total_component = bottom_hole_assemblies[1].components|length%}
# 	{% endif %}
#
# 	{% if total_component < 15%}
#  		{% set  total_rows = 15%}
# 	{% else %}
# 		{% set total_rows = total_component%}
# 	{% endif %}
#
# 	{% set total_bha1 = bottom_hole_assemblies[0].components|length %}
# 	{% set total_bha2 = bottom_hole_assemblies[1].components|length %}
#
# {% for row_index in range (total_rows)%}
#  <tr height="17" style="mso-height-source:userset;height:12.75pt">
#
# 	{% set index1 = row_index%}
# 	{% set index2 = row_index%}
#
#    {%if row_index < total_bha1%}
# 	{% set component_name_1 = bottom_hole_assemblies[0].components[index1].component%}
# 	{% set component_od_1 = bottom_hole_assemblies[0].components[index1].outer_diameter%}
# 	{% set component_length_1 = bottom_hole_assemblies[0].components[index1].length%}
#    {%else%}
#    {% set component_name_1 = ""%}
# 	{% set component_od_1 = ""%}
# 	{% set component_length_1 = ""%}
#    {%endif%}
#
#    {%if row_index < total_bha2%}
# 	{% set component_name_2 = bottom_hole_assemblies[1].components[index2].component%}
# 	{% set component_od_2 = bottom_hole_assemblies[1].components[index2].outer_diameter%}
# 	{% set component_length_2 = bottom_hole_assemblies[1].components[index2].length%}
#    {%else%}
#    {% set component_name_2 = ""%}
# 	{% set component_od_2 = ""%}
# 	{% set component_length_2 = ""%}
#    {%endif%}
#
#    {% if row_index == 0%}
# 	<td height="17" class="xl1012093" dir="LTR" align="left" style="height:12.75pt;
# 	border-top:none">Bit Run</td>
# 	<td class="xl1022093" dir="LTR" style="border-top:none">&nbsp;</td>
# 	<td class="xl1062093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
# 	<td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
# 	<td colspan="2" class="xl762093" dir="LTR" style="border-left:none">&nbsp;{{component_name_1}}</td>
# 	<td class="xl1072093" style="border-top:none">&nbsp;{{component_od_1}}</td>
# 	<td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_length_1}}</td>
# 	<td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
# 	border-left:none">&nbsp;{{component_name_2}}</td>
# 	<td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_od_2}}</td>
# 	<td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_length_2}}</td>
# 	<td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
# 	border-left:none">Next Set MD</td>
# 	<td class="xl862093" dir="LTR" style="border-top:none;border-left:none">ft</td>
# 	<td class="xl1002093" dir="LTR" style="border-top:none">&nbsp;{{next_set_md}}</td>
#
# 	{% if row_index == 1%}
# 	<td height="17" class="xl1012093" dir="LTR" align="left" style="height:12.75pt;
#   border-top:none">Manufacturer</td>
#   <td class="xl1022093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl1062093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-left:none">&nbsp;{{component_name_1}}</td>
#   <td class="xl1072093" style="border-top:none">&nbsp;{{component_od_1}}</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_length_1}}</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
# 	border-left:none">&nbsp;{{component_name_2}}</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_od_2}}</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_length_2}}</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-left:none">Last LOT EMW</td>
#   <td class="xl702093" dir="LTR" style="border-top:none">ppg</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{last_lot_emw}}</td>
#
#   {% if row_index == 2%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">IADC
#   Code</td>
#   <td class="xl712093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl1062093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1082093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-left:none">&nbsp;{{component_name_1}}</td>
#   <td class="xl1072093" style="border-top:none">&nbsp;{{component_od_1}}</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_length_1}}</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
# 	border-left:none">&nbsp;{{component_name_2}}</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_od_2}}</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{component_length_2}}</td>
#   <td colspan="2" class="xl812093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">TOL</td>
#   <td class="xl832093" dir="LTR" style="border-top:none;border-left:none">ft</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;{{tol}}</td>
#
#   {% if row_index == 3%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Jets</td>
#   <td class="xl702093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl1062093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="4" class="xl2002093" dir="LTR" style="border-right:1.0pt solid black;
#   border-left:none">Mud Volumes</td>
#
#   {% if row_index == 4%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Serial
#   #</td>
#   <td class="xl702093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl1062093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">Start</td>
#   <td class="xl842093" dir="LTR" style="border-top:none">bbl</td>
#   <td class="xl1092093" dir="LTR" style="border-top:none">&nbsp;{{start_mud_volume}}</td>
#
#   {% if row_index == 5%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Depth
#   Out</td>
#   <td class="xl702093" dir="LTR" style="border-top:none">ft</td>
#   <td class="xl1062093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">Lost Surface</td>
#   <td class="xl842093" dir="LTR" style="border-top:none">bbl</td>
#   <td class="xl1092093" dir="LTR" style="border-top:none">&nbsp;{{lost_surface_mud_volume}}</td>
#
#   {% if row_index == 6%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Depth
#   In</td>
#   <td class="xl702093" dir="LTR" style="border-top:none">ft</td>
#   <td class="xl1062093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">Lost DH</td>
#   <td class="xl842093" dir="LTR" style="border-top:none">bbl</td>
#   <td class="xl1092093" style="border-top:none">&nbsp;{{lost_dh_mud_volume}}</td>
#
#   {% if row_index == 7%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Meterage</td>
#   <td class="xl702093" dir="LTR" style="border-top:none">ft</td>
#   <td class="xl1102093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">Dumped</td>
#   <td class="xl842093" dir="LTR" style="border-top:none">bbl</td>
#   <td class="xl1092093" style="border-top:none">&nbsp;{{dumped_mud_volume}}</td>
#
#   {% if row_index == 8%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Bit
#   Hours</td>
#   <td class="xl1602093" style="border-top:none">hrs</td>
#   <td class="xl1102093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" style="border-top:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">Built</td>
#   <td class="xl842093" dir="LTR" style="border-top:none">bbl</td>
#   <td class="xl1092093" dir="LTR" style="border-top:none">&nbsp;{{built_mud_volume}}</td>
#
#   {% if row_index == 9%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Nozzles</td>
#   <td class="xl702093" dir="LTR" style="border-top:none">in</td>
#   <td class="xl1062093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td class="xl702093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl2092093" dir="LTR" align="left" style="border-right:.5pt solid black;
#   border-left:none">Ending</td>
#   <td class="xl822093" dir="LTR" style="border-top:none">bbl</td>
#   <td class="xl1112093" dir="LTR" style="border-top:none">&nbsp;{{ending_mud_volume}}</td>
#
#   {% if row_index == 10%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Dull
#   Grade</td>
#   <td class="xl1622093" style="border-top:none">&nbsp;</td>
#   <td class="xl1122093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1042093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="4" class="xl2002093" dir="LTR" style="border-right:1.0pt solid black;
#   border-left:none">Gas</td>
#
#   {% if row_index == 11%}
#   <td colspan="4" height="17" class="xl2892093" dir="LTR" style="border-right:1.0pt solid black;
#   height:12.75pt">Cumulative</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">Max. Gas</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl862093" dir="LTR" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;{{max_gas}}</td>
#
#   {% if row_index == 12%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Footage</td>
#   <td class="xl1132093" dir="LTR" style="border-top:none">ft</td>
#   <td colspan="2" class="xl862093" dir="LTR" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">Conn. Gas</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl862093" dir="LTR" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;{{conn_gas}}</td>
#
#   {% if row_index == 13%}
#   <td height="17" class="xl762093" dir="LTR" style="height:12.75pt;border-top:none">Bit
#   Hours</td>
#   <td class="xl702093" dir="LTR" style="border-top:none">hrs</td>
#   <td colspan="2" class="xl862093" dir="LTR" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl762093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl702093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl1002093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl762093" dir="LTR" style="border-top:none;border-left:none">Trip Gas</td>
#   <td class="xl772093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl862093" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;{{trip_gas}}</td>
#
#   {% if row_index == 14%}
#   <td height="17" class="xl812093" dir="LTR" style="height:12.75pt;border-top:none">ROP</td>
#   <td class="xl832093" dir="LTR" style="border-top:none">ft/hrs</td>
#   <td colspan="2" class="xl2922093" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl812093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl832093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl752093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl812093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl832093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl752093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl812093" dir="LTR" style="border-top:none;border-left:none">Back Gas</td>
#   <td class="xl722093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl2922093" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;{{back_gas}}</td>
#
#   {% if row_index == 15%}
#   <td height="17" class="xl812093" dir="LTR" style="height:12.75pt;border-top:none">&nbsp;</td>
#   <td class="xl832093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl2922093" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl812093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl832093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl752093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td colspan="2" class="xl812093" dir="LTR" style="border-right:.5pt solid black;
#   border-left:none">&nbsp;</td>
#   <td class="xl832093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl752093" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl812093" dir="LTR" style="border-top:none;border-left:none">&nbsp;</td>
#   <td class="xl722093" dir="LTR" style="border-top:none">&nbsp;</td>
#   <td colspan="2" class="xl2922093" style="border-right:1.0pt solid black;
#   border-left:none">&nbsp;</td>
#   {% endif %}
#  {% endfor %}
#
#  {% else %}
#
#  {% endif}

# %%
3//2
# Out:
# 1
